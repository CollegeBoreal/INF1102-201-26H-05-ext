# %%
i = "ouail gacem"
print(i)
# Out:
# ouail gacem

# %%
import random
answers = ["Yes!", "No way.", "Definitely!", "Ask again later...", "Absolutely not.", "For sure!"]
question = input("Ask the Magic 8-Ball: ")
print("🎱", random.choice(answers))
# Out:
# Ask the Magic 8-Ball:  whats my name
# 🎱 Definitely!
