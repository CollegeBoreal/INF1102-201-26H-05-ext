# %% [markdown]
# # Rapport Jupyter - 300150296
#
# ## Étudiant
# Youba Bouanani - 300150296
#
# ## Objectif
# Installation et utilisation de Jupyter Lab avec Miniforge

# %% [markdown]
# ## Installation
#
# ### 1. Miniforge
# ```powershell
# choco install miniforge3 -y
# ```
#
# ### 2. Environnement Python
# ```powershell
# conda create -n INF1102 python=3.12 -y
# conda activate INF1102
# ```

# %% [markdown]
# ## Test Python

# %%
# Test simple Python
print("Hello from Jupyter Lab!")
print("Étudiant: 300150296")

# %%
# Calculs simples
import sys
print(f"Version Python: {sys.version}")

# Liste de nombres
nombres = [1, 2, 3, 4, 5]
print(f"Somme: {sum(nombres)}")
print(f"Moyenne: {sum(nombres)/len(nombres)}")

# %% [markdown]
# ## Conclusion
#
# Jupyter Lab installé et fonctionnel avec succès.
#
# ✅ Miniforge installé
# ✅ Environnement Python créé
# ✅ Jupyter Lab opérationnel
