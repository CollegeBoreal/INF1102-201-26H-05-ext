# %% [markdown]
# # Rapport d'Analyse - 300150296
#
# ## Objectif
# Analyse automatisée de fichiers logs Nginx avec Bash et Python.
#
# ## Méthode
# 1. Script Bash (`analyse.sh`) orchestre l'analyse
# 2. Script Python (`analyse.py`) extrait les statistiques
# 3. Génération automatique de `rapport.txt`
#
# ## Résultats
# Les résultats sont disponibles dans `output/rapport.txt`
#
# ## Conclusion
# Le projet démontre l'utilisation de Bash et Python pour automatiser l'analyse de logs.
