# %% [markdown]
# # Rapport Monitoring Web
# **Étudiant:** Mohib Bekkai
# **Matricule:** 300152260
# **Cours:** INF1102

# %% [markdown]
# ## Objectif
# Ce projet vérifie la disponibilité de plusieurs sites web et mesure les temps de réponse.

# %%
sites = ['google.com', 'github.com', 'youtube.com', 'wikipedia.org', 'stackoverflow.com']
print('Sites monitorés:', sites)

# %% [markdown]
# ## Résultats
# Les résultats sont dans output/rapport.txt
