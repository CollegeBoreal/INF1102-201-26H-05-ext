# %% [markdown]
# # Projet 5 - Monitoring site web
#
# **Etudiant :** Imad Boudeuf
# **Numero :** 300152410
# **Cours :** INF1102-201-26H-05

# %% [markdown]
# ## Objectif
# Surveiller la disponibilite et le temps de reponse de sites web.

# %%
with open('output/rapport.txt') as f:
    print(f.read())

# %% [markdown]
# ## Conclusion
# 300152410 - Les 3 sites surveilles sont disponibles.
